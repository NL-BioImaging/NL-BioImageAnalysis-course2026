# %%
import ezomero
from ezomero import connect
from ezomero import get_image
import matplotlib.pyplot as plt

# %%
# Connect
host = 'omero1.fair-omero-lu.src.surf-hosted.nl'
port = 4064
user = 'nlbi'
secure = True
group = "training"

conn = ezomero.connect(host=host, port=port,user=user,group=group,secure=secure)
# Out:
# Enter password:  ········

# %%
image_id = 251

# %%
img, pix = get_image(conn, image_id, xyzct=True)

# %%
print(conn)
# Out:
# <omero.gateway._BlitzGateway object at 0x000002C04F895DF0>

# %%
type(pix)
# Out:
# numpy.ndarray

# %%
print(pix.shape)
# Out:
# (1024, 1024, 1, 2, 1)

# %%
plt.imshow(px[:,:,0,0,0])

# %%
plt.imshow(px[:,:,0,1,0])
